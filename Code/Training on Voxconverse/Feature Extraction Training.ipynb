# %% [markdown]
# # Feature Extraction From Audio Files
# In this file we will be extracting eccential features from the VoxConverse 2020 dataset. We will parse the transcripts to obatain the timestampe. On those timestamps we will extract data which will include the MFCC features of 1sec audio segments, the true speaker labels, starting and ending time of the segments.

# %%
import os
import sys
import librosa
import numpy as np

# %%
audio_len = 1.0
training_folder = '../Data/Audio_Dataset/Training/'
transcripts_folder = '../Data/Audio_Dataset/Transcripts/'

# %%
def print_progress(done,total):          #For displaying the progress bar while preprocessing audio files
    x = int(done*50.0/total)
    sys.stdout.write('['+str('='*x)+'>'+str('-'*(50-x))+']  '+str(done)+'/'+str(total)+'\r')
    sys.stdout.flush()

def progress(entity):
    print_progress(0,len(entity))
    i = 0
    for ent in entity:
        yield ent
        i+=1
        print_progress(i,len(entity))
    sys.stdout.write("\n")
    sys.stdout.flush()

# %%
def get_mfcc(audio_folder, transcript_folder, audio_len):   # Extracting the features
    speaker_id = 0
    mfcc_store = []
    timestamps = []
    labels = []
    verify = 0
    files = os.listdir(audio_folder)
    file_number = 0
    for file in files:    # Itera
        file_number+=1
        print("Processing File: "+str(file_number)+"/"+str(len(files))+"  ("+file+")")
        store = {}
        transcript_file = transcript_folder+file.split('.')[0]+'.rttm'
        log = open(transcript_file,'r')
        log = log.readlines()
        for line in progress(log):     # Parsing the transcript of the audio file
            words = line.split()
            speaker = words[7]
            if speaker not in store.keys():
                store[speaker] = []
            start = float(words[3])
            duration = float(words[4])
            verify+=int(duration)
            end = start+duration
            while start+audio_len<=end:
                audio,sr = librosa.load(audio_folder+file,sr = 16000,offset = start, duration = audio_len)
                mfcc = librosa.feature.mfcc(y = audio, sr = sr, n_mfcc=40)  # Extracting MFCC features
                mfcc = mfcc.T
                store[speaker].append([mfcc,start])
                start+=audio_len
                
        for key in store:
            limit = 300
            speaker_id+=1
            for mfcc,start in store[key]:    # Collecting the MFCC features corresponding to the labels
                mfcc_store.append(mfcc)
                labels.append(speaker_id)
                timestamps.append([start,start+audio_len])
                limit-=1
                if limit==0: break
                
    return mfcc_store,labels,timestamps,verify

# %%
training_mfcc,training_labels,training_timestamps,verify = get_mfcc(training_folder,transcripts_folder,audio_len)
# Out:
# Processing File: 1/180  (gwtwd.wav)
# [==================================================>]  11/11
# Processing File: 2/180  (jnivh.wav)
# [==================================================>]  17/17
# Processing File: 3/180  (rxgun.wav)
# [==================================================>]  30/30
# Processing File: 4/180  (dhorc.wav)
# [==================================================>]  23/23
# Processing File: 5/180  (ehpau.wav)
# [==================================================>]  36/36
# Processing File: 6/180  (gqdxy.wav)
# [==================================================>]  41/41
# Processing File: 7/180  (kkwkn.wav)
# [==================================================>]  32/32
# Processing File: 8/180  (qppll.wav)
# [==================================================>]  6/6
# Processing File: 9/180  (bkwns.wav)
# [==================================================>]  3/3
# Processing File: 10/180  (cmfyw.wav)
# [==================================================>]  62/62
# Processing File: 11/180  (cyyxp.wav)
# [==================================================>]  28/28
# Processing File: 12/180  (tucrg.wav)
# [==================================================>]  5/5
# Processing File: 13/180  (ndkwv.wav)
# [==================================================>]  86/86
# Processing File: 14/180  (jcako.wav)
# [==================================================>]  217/217
# Processing File: 15/180  (mdbod.wav)
# [==================================================>]  47/47
# Processing File: 16/180  (ioasm.wav)
# [==================================================>]  149/149
# Processing File: 17/180  (szsyz.wav)
# [==================================================>]  7/7
# Processing File: 18/180  (mekog.wav)
# [==================================================>]  76/76
# Processing File: 19/180  (cobal.wav)
# [==================================================>]  3/3
# Processing File: 20/180  (sikkm.wav)
# [==================================================>]  1/1
# Processing File: 21/180  (gpjne.wav)
# [==================================================>]  16/16
# Processing File: 22/180  (pnook.wav)
# [==================================================>]  57/57
# Processing File: 23/180  (oenox.wav)
# [==================================================>]  4/4
# Processing File: 24/180  (qouur.wav)
# [==================================================>]  8/8
# Processing File: 25/180  (rcxzg.wav)
# [==================================================>]  23/23
# Processing File: 26/180  (tjkfn.wav)
# [==================================================>]  43/43
# Processing File: 27/180  (dvngl.wav)
# [==================================================>]  53/53
# Processing File: 28/180  (jyirt.wav)
# [==================================================>]  6/6
# Processing File: 29/180  (cmhsm.wav)
# [==================================================>]  23/23
# Processing File: 30/180  (suuxu.wav)
# [==================================================>]  69/69
# Processing File: 31/180  (bwzyf.wav)
# [==================================================>]  8/8
# Processing File: 32/180  (czlvt.wav)
# [==================================================>]  68/68
# Processing File: 33/180  (iqtde.wav)
# [==================================================>]  4/4
# Processing File: 34/180  (jsdmu.wav)
# [==================================================>]  18/18
# Processing File: 35/180  (tlprc.wav)
# [==================================================>]  19/19
# Processing File: 36/180  (fvyvb.wav)
# [==================================================>]  78/78
# Processing File: 37/180  (syiwe.wav)
# [==================================================>]  6/6
# Processing File: 38/180  (dbugl.wav)
# [==================================================>]  48/48
# Processing File: 39/180  (mesob.wav)
# [==================================================>]  29/29
# Processing File: 40/180  (qsfzo.wav)
# [==================================================>]  9/9
# Processing File: 41/180  (epdpg.wav)
# [==================================================>]  94/94
# Processing File: 42/180  (lfzib.wav)
# [==================================================>]  37/37
# Processing File: 43/180  (ldkmv.wav)
# [==================================================>]  53/53
# Processing File: 44/180  (ikgcq.wav)
# [==================================================>]  20/20
# Processing File: 45/180  (tiams.wav)
# [==================================================>]  12/12
# Processing File: 46/180  (ktzmw.wav)
# [==================================================>]  54/54
# Processing File: 47/180  (sldwj.wav)
# [==================================================>]  20/20
# Processing File: 48/180  (onpra.wav)
# [==================================================>]  28/28
# Processing File: 49/180  (edixl.wav)
# [==================================================>]  13/13
# Processing File: 50/180  (ntchr.wav)
# [==================================================>]  20/20
# Processing File: 51/180  (bydui.wav)
# [==================================================>]  20/20
# Processing File: 52/180  (houcx.wav)
# [==================================================>]  59/59
# Processing File: 53/180  (ooxnm.wav)
# [==================================================>]  28/28
# Processing File: 54/180  (gofnj.wav)
# [==================================================>]  18/18
# Processing File: 55/180  (ampme.wav)
# [==================================================>]  14/14
# Processing File: 56/180  (kiadt.wav)
# [==================================================>]  97/97
# Processing File: 57/180  (qzwxa.wav)
# [==================================================>]  12/12
# Processing File: 58/180  (nxgad.wav)
# [==================================================>]  21/21
# Processing File: 59/180  (hgdez.wav)
# [==================================================>]  127/127
# Processing File: 60/180  (ipqqq.wav)
# [==================================================>]  29/29
# Processing File: 61/180  (hkzpa.wav)
# [==================================================>]  61/61
# Processing File: 62/180  (evtyi.wav)
# [==================================================>]  217/217
# Processing File: 63/180  (odkzj.wav)
# [==================================================>]  53/53
# Processing File: 64/180  (jsmbi.wav)
# [==================================================>]  19/19
# Processing File: 65/180  (kckqn.wav)
# [==================================================>]  26/26
# Processing File: 66/180  (qhesr.wav)
# [==================================================>]  6/6
# Processing File: 67/180  (fkvvo.wav)
# [==================================================>]  51/51
# Processing File: 68/180  (bdopb.wav)
# [==================================================>]  85/85
# Processing File: 69/180  (akthc.wav)
# [==================================================>]  13/13
# Processing File: 70/180  (qydmg.wav)
# [==================================================>]  2/2
# Processing File: 71/180  (tguxv.wav)
# [==================================================>]  15/15
# Processing File: 72/180  (pilgb.wav)
# [==================================================>]  81/81
# Processing File: 73/180  (jhdav.wav)
# [==================================================>]  10/10
# Processing File: 74/180  (qpylu.wav)
# [==================================================>]  9/9
# Processing File: 75/180  (asxwr.wav)
# [==================================================>]  18/18
# Processing File: 76/180  (nctdh.wav)
# [==================================================>]  15/15
# Processing File: 77/180  (eqttu.wav)
# [==================================================>]  5/5
# Processing File: 78/180  (spzmn.wav)
# [==================================================>]  5/5
# Processing File: 79/180  (ggvel.wav)
# [==================================================>]  37/37
# Processing File: 80/180  (plbbw.wav)
# [==================================================>]  7/7
# Processing File: 81/180  (praxo.wav)
# [==================================================>]  48/48
# Processing File: 82/180  (kklpv.wav)
# [==================================================>]  45/45
# Processing File: 83/180  (imbqf.wav)
# [==================================================>]  48/48
# Processing File: 84/180  (migzj.wav)
# [==================================================>]  66/66
# Processing File: 85/180  (nrogz.wav)
# [==================================================>]  69/69
# Processing File: 86/180  (mvjuk.wav)
# [==================================================>]  50/50
# Processing File: 87/180  (aufkn.wav)
# [==================================================>]  12/12
# Processing File: 88/180  (djqif.wav)
# [==================================================>]  30/30
# Processing File: 89/180  (fsaal.wav)
# [==================================================>]  17/17
# Processing File: 90/180  (cwryz.wav)
# [==================================================>]  19/19
# Processing File: 91/180  (cqaec.wav)
# [==================================================>]  59/59
# Processing File: 92/180  (tfvyr.wav)
# [==================================================>]  2/2
# Processing File: 93/180  (crixb.wav)
# [==================================================>]  59/59
# Processing File: 94/180  (kctgl.wav)
# [==================================================>]  10/10
# Processing File: 95/180  (txcok.wav)
# [==================================================>]  38/38
# Processing File: 96/180  (hqyok.wav)
# [==================================================>]  3/3
# Processing File: 97/180  (grzbb.wav)
# [==================================================>]  44/44
# Processing File: 98/180  (azisu.wav)
# [==================================================>]  28/28
# Processing File: 99/180  (aisvi.wav)
# [==================================================>]  42/42
# Processing File: 100/180  (uexjc.wav)
# [==================================================>]  51/51
# Processing File: 101/180  (kkghn.wav)
# [==================================================>]  113/113
# Processing File: 102/180  (tcwsn.wav)
# [==================================================>]  28/28
# Processing File: 103/180  (hiyis.wav)
# [==================================================>]  3/3
# Processing File: 104/180  (fxgvy.wav)
# [==================================================>]  2/2
# Processing File: 105/180  (mpvoh.wav)
# [==================================================>]  35/35
# Processing File: 106/180  (kefgo.wav)
# [==================================================>]  33/33
# Processing File: 107/180  (udjij.wav)
# [==================================================>]  109/109
# Processing File: 108/180  (qjgpl.wav)
# [==================================================>]  15/15
# Processing File: 109/180  (usbgm.wav)
# [==================================================>]  3/3
# Processing File: 110/180  (uvnmy.wav)
# [==================================================>]  12/12
# Processing File: 111/180  (irvat.wav)
# [==================================================>]  22/22
# Processing File: 112/180  (kbkon.wav)
# [==================================================>]  23/23
# Processing File: 113/180  (sduml.wav)
# [==================================================>]  57/57
# Processing File: 114/180  (gqbvk.wav)
# [==================================================>]  14/14
# Processing File: 115/180  (nfqjx.wav)
# [==================================================>]  97/97
# Processing File: 116/180  (ppgjx.wav)
# [==================================================>]  71/71
# Processing File: 117/180  (iqbww.wav)
# [==================================================>]  19/19
# Processing File: 118/180  (ngyrk.wav)
# [==================================================>]  22/22
# Processing File: 119/180  (iwdjy.wav)
# [==================================================>]  54/54
# Processing File: 120/180  (sqkup.wav)
# [==================================================>]  38/38
# Processing File: 121/180  (jtagk.wav)
# [==================================================>]  35/35
# Processing File: 122/180  (mwfmq.wav)
# [==================================================>]  8/8
# Processing File: 123/180  (pgkde.wav)
# [==================================================>]  29/29
# Processing File: 124/180  (afjiv.wav)
# [==================================================>]  28/28
# Processing File: 125/180  (uatlu.wav)
# [==================================================>]  28/28
# Processing File: 126/180  (ahnss.wav)
# [==================================================>]  87/87
# Processing File: 127/180  (jiqvr.wav)
# [==================================================>]  23/23
# Processing File: 128/180  (kdfqk.wav)
# [==================================================>]  170/170
# Processing File: 129/180  (abjxc.wav)
# [==================================================>]  2/2
# Processing File: 130/180  (hycgx.wav)
# [==================================================>]  21/21
# Processing File: 131/180  (pnyir.wav)
# [==================================================>]  43/43
# Processing File: 132/180  (nnqfq.wav)
# [==================================================>]  27/27
# Processing File: 133/180  (bspxd.wav)
# [==================================================>]  61/61
# Processing File: 134/180  (luvfz.wav)
# [==================================================>]  53/53
# Processing File: 135/180  (ezsgk.wav)
# [==================================================>]  52/52
# Processing File: 136/180  (gocbm.wav)
# [==================================================>]  21/21
# Processing File: 137/180  (djngn.wav)
# [==================================================>]  8/8
# Processing File: 138/180  (ulriv.wav)
# [==================================================>]  64/64
# Processing File: 139/180  (pqmho.wav)
# [==================================================>]  3/3
# Processing File: 140/180  (qrzjk.wav)
# [==================================================>]  2/2
# Processing File: 141/180  (atgpi.wav)
# [==================================================>]  6/6
# Processing File: 142/180  (lknjp.wav)
# [==================================================>]  8/8
# Processing File: 143/180  (mkrcv.wav)
# [==================================================>]  76/76
# Processing File: 144/180  (mgpok.wav)
# [==================================================>]  56/56
# Processing File: 145/180  (ufpel.wav)
# [==================================================>]  69/69
# Processing File: 146/180  (qvtia.wav)
# [==================================================>]  83/83
# Processing File: 147/180  (kszpd.wav)
# [==================================================>]  15/15
# Processing File: 148/180  (eapdk.wav)
# [==================================================>]  27/27
# Processing File: 149/180  (jynhe.wav)
# [==================================================>]  60/60
# Processing File: 150/180  (paibn.wav)
# [==================================================>]  12/12
# Processing File: 151/180  (rtvuw.wav)
# [==================================================>]  11/11
# Processing File: 152/180  (femmv.wav)
# [==================================================>]  22/22
# Processing File: 153/180  (blwmj.wav)
# [==================================================>]  20/20
# Processing File: 154/180  (goyli.wav)
# [==================================================>]  57/57
# Processing File: 155/180  (falxo.wav)
# [==================================================>]  140/140
# Processing File: 156/180  (mjgil.wav)
# [==================================================>]  27/27
# Processing File: 157/180  (ccokr.wav)
# [==================================================>]  51/51
# Processing File: 158/180  (sosnj.wav)
# [==================================================>]  37/37
# Processing File: 159/180  (jyflp.wav)
# [==================================================>]  61/61
# Processing File: 160/180  (qygfk.wav)
# [==================================================>]  57/57
# Processing File: 161/180  (bauzd.wav)
# [==================================================>]  83/83
# Processing File: 162/180  (ldnro.wav)
# [==================================================>]  82/82
# Processing File: 163/180  (gzvkx.wav)
# [==================================================>]  21/21
# Processing File: 164/180  (mevkw.wav)
# [==================================================>]  16/16
# Processing File: 165/180  (imtug.wav)
# [==================================================>]  14/14
# Processing File: 166/180  (qfdpp.wav)
# [==================================================>]  15/15
# Processing File: 167/180  (cjfer.wav)
# [==================================================>]  88/88
# Processing File: 168/180  (mqxsf.wav)
# [==================================================>]  72/72
# Processing File: 169/180  (dscgs.wav)
# [==================================================>]  34/34
# Processing File: 170/180  (kuduk.wav)
# [==================================================>]  53/53
# Processing File: 171/180  (bxpwa.wav)
# [==================================================>]  18/18
# Processing File: 172/180  (oklol.wav)
# [==================================================>]  146/146
# Processing File: 173/180  (oxxwk.wav)
# [==================================================>]  45/45
# Processing File: 174/180  (eziem.wav)
# [==================================================>]  21/21
# Processing File: 175/180  (oekmc.wav)
# [==================================================>]  11/11
# Processing File: 176/180  (bravd.wav)
# [==================================================>]  73/73
# Processing File: 177/180  (tplwz.wav)
# [==================================================>]  38/38
# Processing File: 178/180  (hgeec.wav)
# [==================================================>]  19/19
# Processing File: 179/180  (esrit.wav)
# [==================================================>]  22/22
# Processing File: 180/180  (exymw.wav)
# [==================================================>]  9/9

# %%
print(len(training_mfcc),len(training_labels),len(training_timestamps),verify)
# Out:
# 52153 52153 52153 56013

# %%
np.save('../Data/MFCC_Features/Training/training_mfcc',training_mfcc)       #Saving files obtained
np.save('../Data/MFCC_Features/Training/training_labels',training_labels)
np.save('../Data/MFCC_Features/Training/training_timestamps',training_timestamps)
